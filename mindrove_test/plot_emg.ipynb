# %%
import numpy as np
import pandas as pd

# %%
data = [
    "data/EMG/subject_0_EMG.csv",
    "data/EMG/subject_1_EMG.csv",
    "data/EMG/subject_2_EMG.csv",
    "data/EMG/subject_3_EMG.csv",
    "data/EMG/subject_4_EMG.csv",
    "data/EMG/subject_5_EMG.csv"
]

dataframes = []
for i in data:
    df = pd.read_csv(i)
    dataframes.append(df)
print(dataframes[5])    
#df_emg0
# Out:
#        Sample_num  Task_number      EMG1      EMG2      EMG3      EMG4  \
# 0             0.0          0.0  144467.0  218195.0  365528.0  333131.0
# 1             1.0          0.0  144409.0  218136.0  365438.0  333034.0
# 2             2.0          0.0  144458.0  218135.0  365438.0  333029.0
# 3             3.0          0.0  144389.0  218054.0  365401.0  332998.0
# 4             4.0          0.0  144499.0  218213.0  365555.0  333148.0
# ...           ...          ...       ...       ...       ...       ...
# 37660     37660.0          0.0  165806.0  174254.0  361003.0  326916.0
# 37661     37661.0          0.0  165741.0  174177.0  361178.0  327055.0
# 37662     37662.0          0.0  166086.0  174733.0  362035.0  327877.0
# 37663     37663.0          0.0  166004.0  174745.0  362112.0  328004.0
# 37664     37664.0          0.0  166191.0  174969.0  362386.0  328352.0
#
#            EMG5      EMG6     EMG7      EMG8     Timestamp  Video_timestamp  \
# ...

# %% [markdown]
# # Task 1
# Selccionar solo los datos del emg indicato por el id y plotearlos

# %%
#Plot single EMG channel
import pandas as pd
import matplotlib.pyplot as plt

id = 4
dataval= dataframes[id]
emg_id = 6
columnemg = emg_id + 1
emgval = dataval.iloc[:,columnemg] * 0.045
time = dataval.iloc[:,10] - dataval.iloc[0,10]

plt.plot(time, emgval,linewidth=0.5)
plt.xlabel('Time (sec)',fontname="Times New Roman",fontweight=15)
plt.ylabel('EMG values (microVolts)',fontname="Times New Roman")

plt.xlim([26, 32])
plt.ylim(8000, 13000)
plt.show()

# %%
#DIBUJO POR COLORES
id = 4
dataval= dataframes[id]
emg_id = 6
columnemg = emg_id + 1
emgval = dataval.iloc[:,columnemg] * 0.045
time = dataval.iloc[:,10] - dataval.iloc[0,10]
taskcolumn = dataval.iloc[:,1]
store0=[]
store1=[]
store2=[]
store3=[]
store4=[]
store5=[]
store6=[]
store7=[]

for p in range(len(taskcolumn)):
    if taskcolumn[p] == 1:
       store1.append(p)
    elif taskcolumn[p] == 2:
       store2.append(p)
    elif taskcolumn[p] == 3:
       store3.append(p)
    elif taskcolumn[p] == 4:
       store4.append(p)
    elif taskcolumn[p] == 5:
       store5.append(p)
    elif taskcolumn[p] == 6:
       store6.append(p)
    elif taskcolumn[p] == 7:
       store7.append(p)
    elif taskcolumn[p] == 0:
       store0.append(p)

#plt.plot(time[store0],emgval[store0],'gray')  
plt.plot(time, emgval,'gray',linewidth=0.5)      
plt.plot(time[store1],emgval[store1],'r',linewidth=0.5)
plt.plot(time[store2],emgval[store2],'b',linewidth=0.5)
plt.plot(time[store3],emgval[store3],'g',linewidth=0.5)
plt.plot(time[store4],emgval[store4],'m',linewidth=0.5)
plt.plot(time[store5],emgval[store5],'y',linewidth=0.5)
plt.plot(time[store6],emgval[store6],'cadetblue',linewidth=0.5)
plt.plot(time[store7],emgval[store7],'darkorange',linewidth=0.5)


L = plt.legend(["Idle","Thumb flexion","Index finger flexion","Middle finger flexion","Ring finger flexion","Pinky finger flexion","Wrist extension (outward)","Wrist flexion (inward)"],loc ='lower right',prop={'size':7}, ncol = 2)      
plt.setp(L.texts, family='Times New Roman',fontsize = 10)
plt.tight_layout()
plt.xlim([28, 29])
plt.ylim(8000, 13000)
plt.xlabel('Time (secs)',fontname="Times New Roman",fontweight=15)
plt.ylabel('EMG values (microVolts)',fontname="Times New Roman")
plt.title('EMG Channel #1, Subject #3',fontname="Times New Roman", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'EMG Channel #1, Subject #3')

# %% [markdown]
# # Task 2
# Selccionar solo los datos que tengan el task indicado del emg indicado

# %%
task_number = 7
taskcolumn = 1
emgval = np.zeros(len(dataval))
for i, row in dataval.iterrows():
    if row[taskcolumn] == task_number:
        emgval[i] = row[columnemg] * 0.045
    else:
        emgval[i] = 0
print(emgval)   
plt.plot(time, emgval)
plt.xlabel('Time (secs)',fontname="Times New Roman",fontweight=15)
plt.ylabel('EMG values (microVolts)',fontname="Times New Roman")
plt.title('EMG val of certain task',fontname="Times New Roman", fontweight="bold")        
#plt.show()
# Out:
# [0. 0. 0. ... 0. 0. 0.]
# Text(0.5, 1.0, 'EMG val of certain task')

# %% [markdown]
# # Task 3
# Selccionar solo los datos que tengan el task indicado de todos los emgs

# %%
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
fig, axs = plt.subplots(4, 2)
id = 2
#dataval= dataframes[id]
dataval = pd.read_csv("data/EMG/nacho.csv", delimiter = ";", decimal = ",")

emgval = dataval.iloc[0:,0:8] 

time = list(range(0, 31429))
axs[0, 0].plot(time,emgval.iloc[:,0] )
axs[0, 0].set_title('EMG channel #1', fontname="Times New Roman", fontweight="bold")

axs[0, 1].plot(time, emgval.iloc[:,1])
axs[0, 1].set_title('EMG channel #2', fontname="Times New Roman", fontweight="bold")

axs[1, 0].plot(time, emgval.iloc[:,2])
axs[1, 0].set_title('EMG channel #3', fontname="Times New Roman", fontweight="bold")

axs[1, 1].plot(time, emgval.iloc[:,3])
axs[1, 1].set_title('EMG channel #4',  fontname="Times New Roman", fontweight="bold")

axs[2, 0].plot(time, emgval.iloc[:,4])
axs[2, 0].set_title('EMG channel #5', fontname="Times New Roman", fontweight="bold")

axs[2, 1].plot(time, emgval.iloc[:,5])
axs[2, 1].set_title('EMG channel #6', fontname="Times New Roman", fontweight="bold")

axs[3, 0].plot(time, emgval.iloc[:,6])
axs[3, 0].set_title('EMG channel #7', fontname="Times New Roman", fontweight="bold")

axs[3, 1].plot(time, emgval.iloc[:,7])
axs[3, 1].set_title('EMG channel #8', fontname="Times New Roman", fontweight="bold")


plt.tight_layout()
plt.show()



#meterlo en un for

# %%
#todos los channels de un id por colores
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
id = 3
dataval= pd.read_csv("prueba_dataset.csv")
emgval = dataval.iloc[:,2:10] * 0.045
dataval= dataframes[id]
emgval = abs(dataval.iloc[:,2:10])
emg_id = 1
columnemg = emg_id + 1
#emgval = dataval.iloc[:,columnemg] * 0.045
time = dataval.iloc[:,10] - dataval.iloc[0,10]
end = len(time)-1
taskcolumn = dataval.iloc[:,1]
fig1, axs1 = plt.subplots(4, 2)


#emgval = dataval.iloc[:,2:10] * 0.045
titles = ['EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']

for i, ax in enumerate(axs1.flat):
    store0=[]
    store1=[]
    store2=[]
    store3=[]
    store4=[]
    store5=[]
    store6=[]
    store7=[]
    for p in range(len(taskcolumn)):
         if taskcolumn[p] == 1:
            store1.append(p)
         elif taskcolumn[p] == 2:
            store2.append(p)
         elif taskcolumn[p] == 3:
            store3.append(p)
         elif taskcolumn[p] == 4:
            store4.append(p)
         elif taskcolumn[p] == 5:
            store5.append(p)
         elif taskcolumn[p] == 6:
            store6.append(p)
         elif taskcolumn[p] == 7:
            store7.append(p)
         elif taskcolumn[p] == 0:
            store0.append(p)
            
    ax.plot(time, emgval.iloc[:,i],'gray',linewidth=0.5, label = "Idle")      
    ax.plot(time[store1],emgval.iloc[store1,i],'r',linewidth=0.5, label = "TF")
    ax.plot(time[store2],emgval.iloc[store2,i],'b',linewidth=0.5, label = "IFF" )
    ax.plot(time[store3],emgval.iloc[store3,i],'g',linewidth=0.5, label = "MFF")
    ax.plot(time[store4],emgval.iloc[store4,i],'m',linewidth=0.5, label = "RFF")
    ax.plot(time[store5],emgval.iloc[store5,i],'y',linewidth=0.5, label = "PFF")
    ax.plot(time[store6],emgval.iloc[store6,i],'cadetblue',linewidth=0.5, label = "WE")
    ax.plot(time[store7],emgval.iloc[store7,i],'darkorange',linewidth=0.5, label = "WF")
    #ax.plot(time,emgval.iloc[:,i])
    ax.set_title(titles[i],fontname="Times New Roman", fontweight="bold",fontsize=9)
    ax.set_xlabel('Time (sec)',fontname="Times New Roman",fontsize=9)
    ax.set_ylabel('ADC abs values',fontname="Times New Roman",fontsize=7)
    ax.tick_params(axis='both', labelsize=8)
    ax.set_xlim([0, time[end]])
    

plt.tight_layout()
L = ax.legend(loc='center', bbox_to_anchor=(1.2, 4.1),fontsize = 9)
plt.setp(L.texts, family='Times New Roman')
plt.suptitle('RECTIFIED DATA', fontname="Times New Roman", fontweight="bold",fontsize=12)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 7
#       4 import pandas as pd
#       6 id = 3
# ----> 7 dataval= pd.read_csv("prueba.csv")
#       8 emgval = abs(dataval.iloc[:,2:10])
#       9 emg_id = 1
#
# File c:\Users\sofia\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\sofia\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %% [markdown]
# # Task 4
# Selccionar solo los datos que tengan el task indicado, de todos los emg, con el tiempo como X

# %%
import matplotlib.pyplot as plt
fig1, axs1 = plt.subplots(4, 2)
id = 2
dataval= dataframes[id]

emgval = dataval.iloc[:,2:10] * 0.045
time = dataval.iloc[:,10] - dataval.iloc[0,10]

titles = ['EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']
for i, ax in enumerate(axs1.flat):
    ax.plot(time,emgval.iloc[:,i])
    ax.set_title(titles[i],fontname="Times New Roman", fontweight="bold",fontsize=10)
    ax.set_xlabel('Time (secs)',fontname="Times New Roman",fontsize=10)
    ax.set_ylabel('EMG (microVolts)',fontname="Times New Roman",fontsize=7)

plt.tight_layout()
plt.show()

end = len(time)

# %% [markdown]
# # Task 5
# Sacar el valor medio de cada EMG para cada task, para cada repeticion

# %%
#ESTE NO UTILIZADO
#BORRADOR TODOS LOS SUBJECTS
from statistics import mean
import numpy as np
import pandas as pd
import statistics
id = 2
dataval= dataframes[id]
emgval = dataval.iloc[:,2:10] * 0.045
numemg = [1,2,3,4,5,6,7,8]
tasks = [1,2,3,4,5,6,7]
tasksnames = ['Thumb flexion', 'Index finger flexion','Middle finger flexion','Ring finger flexion', 'Pinky finger flexion','Wrist extension (outward)','Wrist flexion (inward)' ]
taskcolumn = 1
taskval = dataval.iloc[:,taskcolumn]
task = np.zeros((3,9))
#new dataframe contaning all the media, for all sucjects, for all tasks, for each rep
dataframetaskmedia = []
indtask = []
titles = ['Task number','EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']
indexs = ['rep 1','rep 2','rep 3' ]

for m in dataframes:

    for k,val in enumerate(tasks):
        #title = ('TASK NUMBER #', val, ':', tasksnames[k])
        rep = 0
        start = 0
        tasksaved = pd.DataFrame()
      
        for j in range(len(taskval)):
            if taskval[j] == tasks[k] and taskval[j-1] == 0:
                start = j
            elif taskval[j] == tasks[k] and taskval[j + 1] == 0:
                count = 1
                for i in numemg:
                    media = emgval.iloc[start:j,count-1]
                    task[rep,count] = statistics.mean(media)
                    count = count + 1
                task[rep,0] = tasks[k]
                rep = rep + 1
                start = 0
        
        #tasksaved: save each task result for each subject
                tasksaved = pd.DataFrame(data = task, index = indexs, columns=titles)
        #tasksaved.rename_axis(["TASK NUMBER #", val, ':', tasksnames[k]], axis="columns", inplace=True), me gustaria poner un titulo que cambie por task
    #indtask: save for each subject the whole tasks results
                indtask.append(tasksaved)
   
 #dataframetaskmedia: save all    
    dataframetaskmedia.append(indtask)
# Out:
# [[       Task number  EMG channel #1  EMG channel #2  EMG channel #3  \
# rep 1          7.0     8824.490883    10766.807182    13452.110065
# rep 2          7.0     9075.617439    10741.409146    13542.115000
# rep 3          7.0     9315.098980    10750.794696    13574.052430
#
#        EMG channel #4  EMG channel #5  EMG channel #6  EMG channel #7  \
# rep 1     9044.744961     8313.636857    17742.081506     4424.370662
# rep 2     9087.531585     8164.483415    17705.878049     4544.116585
# rep 3     9094.720217     7935.165390    17700.536421     4542.691139
#
#        EMG channel #8
# rep 1   -18114.667364
# rep 2   -17874.404268
# rep 3   -17747.200054  ,        Task number  EMG channel #1  EMG channel #2  EMG channel #3  \
# rep 1          7.0     8824.490883    10766.807182    13452.110065
# rep 2          7.0     9075.617439    10741.409146    13542.115000
# rep 3          7.0     9315.098980    10750.794696    13574.052430
#
# ...

# %%
#ESTE NO UTILIZADO
#BORRADOR  2

from statistics import mean
import numpy as np
import pandas as pd
import statistics

dataval = dataframes[5]
emgval = dataval.iloc[:,2:10] * 0.045
numemg = [1,2,3,4,5,6,7,8]
tasks = [1,2,3,4,5,6,7]
tasksnames = ['Thumb flexion', 'Index finger flexion','Middle finger flexion','Ring finger flexion', 'Pinky finger flexion','Wrist extension (outward)','Wrist flexion (inward)' ]
taskcolumn = 1
taskval = dataval.iloc[:,taskcolumn]
task = np.zeros((3,9))
#new dataframe contaning all the media, for all subjects, for all tasks, for each rep
dataframetaskmedia = []

titles = ['Task number','EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']
indexs = ['rep 1','rep 2','rep 3' ]

for m in dataframes:
    indtask = []
    for k,val in enumerate(tasks):
        rep = 0
        start = 0
        tasksaved = pd.DataFrame()
      
        for j in range(len(taskval)):
            if taskval[j] == tasks[k] and taskval[j-1] == 0:
                start = j
            elif taskval[j] == tasks[k] and taskval[j + 1] == 0:
                count = 1
                for i in numemg:
                    media = emgval.iloc[start:j,count-1]
                    task[rep,count] = statistics.mean(media)
                    count = count + 1
                task[rep,0] = tasks[k]
                rep = rep + 1
                start = 0
        #tasksaved: save each task result for each subject
                tasksaved = pd.DataFrame(data = task, index = indexs, columns=titles)
    #indtask: save for each subject the whole tasks results
                indtask.append(tasksaved)
    #dataframetaskmedia: save all    
    dataframetaskmedia.append(indtask)

# %%
#MEDIA SOLO DE UN SUBJECT (#3)
from statistics import mean
import numpy as np
import pandas as pd
import statistics

dataval= dataframes[5]
#abs 
emgval = np.abs(dataval.iloc[:,2:10] * 0.045)
numemg = [1,2,3,4,5,6,7,8]
tasks = [1,2,3,4,5,6,7]
taskval = dataval.iloc[:,1]
task = np.zeros((21,9)) #each row

indtask = []
titles = ['Task number','EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']

row = 0
for k,val in enumerate(tasks):
    start = 0
    tasknumber = tasks [k]
    for j in range(len(taskval)-1):
        if taskval[j] == tasknumber and taskval[j-1] == 0:
            start = j
        elif taskval[j] == tasknumber and taskval[j + 1] == 0:
            count = 0
            for i in numemg:
                media = emgval.iloc[start:j,count]
                task[row,count+1] = statistics.mean(media)
                count = count + 1
                
            task[row,0] = tasknumber
            indtask.append(task)
            row = row +1
            
    indtask.append(task)
print(indtask)
# Out:
# [array([[1.00000000e+00, 6.58487559e+03, 9.50561269e+03, 1.63609263e+04,
#         1.49389854e+04, 2.50690389e+04, 1.21077148e+04, 1.59152231e+03,
#         1.62643597e+04],
#        [1.00000000e+00, 6.61870504e+03, 9.51369241e+03, 1.63849254e+04,
#         1.49638781e+04, 2.49183572e+04, 1.20759177e+04, 1.60434947e+03,
#         1.62490194e+04],
#        [1.00000000e+00, 7.13982793e+03, 9.49329173e+03, 1.63966152e+04,
#         1.49752774e+04, 2.47722887e+04, 1.20358413e+04, 1.59927635e+03,
#         1.62614864e+04],
#        [2.00000000e+00, 6.68642943e+03, 9.20668800e+03, 1.64054603e+04,
#         1.49884436e+04, 2.45693383e+04, 1.17849264e+04, 1.52202600e+03,
#         1.63200954e+04],
#        [2.00000000e+00, 6.69089605e+03, 9.15771766e+03, 1.63910895e+04,
#         1.49746869e+04, 2.44865694e+04, 1.17700384e+04, 1.52088075e+03,
#         1.63248562e+04],
#        [2.00000000e+00, 6.68722627e+03, 9.12215797e+03, 1.63935425e+04,
# ...

# %%
#MEDIA SOLO DE UN SUBJECT (#3) VERSION 2 MISMOS RESULTADOS + TASK NUMBER
from statistics import mean
import numpy as np
import pandas as pd
import statistics

dataval = dataframes[5]
#absolute value
emgval = np.abs(dataval.iloc[:,2:10] * 0.045 )
numemg = [1,2,3,4,5,6,7,8]
tasks = [1,2,3,4,5,6,7]
taskval = dataval.iloc[:,1]
indtask1 = np.zeros((21, 9))
titles = ['Task number','EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']
indtask1 = np.array([tuple(row) for row in indtask1], dtype=[(title, float) for title in titles])

#TASK 1,2,3,4,5,6,7
row = 0
for k, tasknumber in enumerate(tasks):
    start = 0
    for j in range(1,(len(taskval))):
        if taskval[j] == tasknumber and taskval[j-1] == 0:
            start = j
        elif taskval[j] == tasknumber and taskval[j + 1] == 0:
            count = 0
            end = j
            for i in numemg:
                segment = emgval.iloc[(start):(end+1),count]
                indtask1[row][count+1] = statistics.mean(segment)
                count += 1
                
            indtask1[row][0] = tasknumber
            row += 1

#TASK 0 

indtask2 = np.zeros((22, 9))
titles = ['Task number','EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']
indtask2 = np.array([tuple(row) for row in indtask2], dtype=[(title, float) for title in titles])
row = 0
start = 0
for j in range(1,(len(taskval))-1):
    if taskval[j] == 0 and taskval[j-1] in range(1, 8):
        start = j
    elif taskval[j] == 0 and taskval[j+1] in range(1, 8):
        count = 0
        end = j
        for i in numemg:
            segment = emgval.iloc[(start):(end+1),count]
            indtask2[row][count+1] = statistics.mean(segment)
            count += 1
        indtask2[row][0] = 0
        row += 1
#last segment
end = j+1
count = 0
for i in numemg:
    segment = emgval.iloc[(start):(end+1),count]
    indtask2[row][count+1] = statistics.mean(segment)
    count += 1
indtask2[row][0] = 0

indtask = np.append(indtask2, indtask1)
print(indtask)
# Out:
# [(0., 6581.82181629, 9700.92709265, 16401.14277796, 14903.48741693, 22845.42486422, 11702.33405751, 1880.74692652, 16091.18096166)
#  (0., 6602.13231308, 9507.3846729 , 16369.425     , 14947.50995327, 25001.96803738, 12075.84126168, 1597.49705607, 16257.08439252)
#  (0., 6678.67181818, 9517.94545455, 16401.54727273, 14978.89318182, 24845.38954545, 12044.15772727, 1607.63954545, 16247.33136364)
#  (0., 6740.07399344, 9379.65536078, 16439.51452047, 15017.26912237, 24462.23271545, 11874.27569667, 1584.82938023, 16285.9101097 )
#  (0., 6687.8709593 , 9176.79584302, 16387.1934593 , 14977.60718023, 24504.10848837, 11745.01020349, 1508.63049419, 16327.6040407 )
#  (0., 6688.2935625 , 9137.10225   , 16391.758875  , 14982.8415    , 24431.9274375 , 11733.1858125 , 1500.219     , 16339.0989375 )
#  (0., 6752.59013812, 9064.38198895, 16407.11132597, 15006.54582873, 24455.295     , 11704.46759669, 1441.04773481, 16378.58303867)
# ...

# %% [markdown]
# # Task 6
# Crear un dataframe nuevo, con columnas Task, EMG_0_media, ..., EMG_8_media
#
# La tabla debe contener una fila por cada subject e intento

# %%
#DENTRO DEL TASK 5

# %% [markdown]
# NORMALIZATION

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
import numpy as np

id = 3
dataval= dataframes[id]
emgval = np.abs(dataval.iloc[:,2:10] * 0.045)

data = np.array(emgval)
# data is stored in a numpy array called 'data'
# with shape (n_samples, 8) where n_samples is the number of samples
# and 8 is the number of channels

# Create an empty array to store the normalized data
normalized_data = np.empty_like(data)

# Create a scaler object for each channel
scalers = []

for i in range(data.shape[1]):
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data[:, i].reshape(-1, 1))
    scalers.append(scaler)
# Normalize each channel separately
for i, scaler in enumerate(scalers):
    normalized_data[:, i] = scaler.transform(data[:, i].reshape(-1, 1)).flatten()
    
# The normalized_data array contains the normalized data
print(normalized_data)
np.savetxt("NORMALIZED1.csv", normalized_data, delimiter=",")
# Out:
# [[-0.64822871 -0.86854176 -0.65898228 ... -0.86778279 -0.5238574
#    0.43094591]
#  [-0.6580174  -0.87499764 -0.67069921 ... -0.86606498 -0.55455881
#    0.4440482 ]
#  [-0.67221877 -0.88532327 -0.69324479 ... -0.87563566 -0.55111747
#    0.45513958]
#  ...
#  [ 0.57265382  0.94510618  0.03574299 ...  0.56850127  0.3877117
#    0.50220728]
#  [ 0.59055314  0.95294007  0.04961719 ...  0.57883543  0.39780373
#    0.47490299]
#  [ 0.58123058  0.94537046  0.03434711 ...  0.57646321  0.40383574
#    0.4741489 ]]

# %%
#DIBUJO CHANNEL 1 NORMALIZED

id = 3
dataval= dataframes[id]
norm = pd.DataFrame(normalized_data)
taskcolumn = norm.iloc[:,0]
emg_id = 1
columnemg = emg_id + 1
#emgval = dataval.iloc[:,columnemg] * 0.045
time = dataval.iloc[:,10] - dataval.iloc[0,10]
end = len(time)-1
taskcolumn = dataval.iloc[:,1]
emgval = norm.iloc[:,0]


time = dataval.iloc[:,10] - dataval.iloc[0,10]

store0=[]
store1=[]
store2=[]
store3=[]
store4=[]
store5=[]
store6=[]
store7=[]

for p in range(len(taskcolumn)):
    if taskcolumn[p] == 1:
       store1.append(p)
    elif taskcolumn[p] == 2:
       store2.append(p)
    elif taskcolumn[p] == 3:
       store3.append(p)
    elif taskcolumn[p] == 4:
       store4.append(p)
    elif taskcolumn[p] == 5:
       store5.append(p)
    elif taskcolumn[p] == 6:
       store6.append(p)
    elif taskcolumn[p] == 7:
       store7.append(p)
    elif taskcolumn[p] == 0:
       store0.append(p)

#plt.plot(time[store0],emgval[store0],'gray')  
plt.plot(time, emgval,'gray',linewidth=0.5)      
plt.plot(time[store1],emgval[store1],'r',linewidth=0.5)
plt.plot(time[store2],emgval[store2],'b',linewidth=0.5)
plt.plot(time[store3],emgval[store3],'g',linewidth=0.5)
plt.plot(time[store4],emgval[store4],'m',linewidth=0.5)
plt.plot(time[store5],emgval[store5],'y',linewidth=0.5)
plt.plot(time[store6],emgval[store6],'cadetblue',linewidth=0.5)
plt.plot(time[store7],emgval[store7],'darkorange',linewidth=0.5)

plt.xlabel('Time(sec)',fontname="Times New Roman",fontweight=15)
plt.ylabel('(%)',fontname="Times New Roman")
plt.title('NORMALIZED CHANNEL',fontname="Times New Roman", fontweight="bold")
end = len(time)-1
plt.xlim([0, time[end]])
plt.ylim(-1,1)

L = plt.legend(["Idle","TF","IFF","MFF","RFF","PFF","WE","WF"],loc ='lower right',prop={'size':7}, ncol = 2)      
plt.setp(L.texts, family='Times New Roman',fontsize = 10)
plt.show()

# %%
#PLOT NNORMALIZATION
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


id = 3
dataval= dataframes[id]
emgval = np.abs(dataval.iloc[:,2:10] * 0.045)
emg_id = 1
columnemg = emg_id + 1
#emgval = dataval.iloc[:,columnemg] * 0.045
time = dataval.iloc[:,10] - dataval.iloc[0,10]
end = len(time)-1
taskcolumn = dataval.iloc[:,1]
fig1, axs1 = plt.subplots(4, 2)


#emgval = dataval.iloc[:,2:10] * 0.045
titles = ['EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']

norm = pd.DataFrame(normalized_data)

for i, ax in enumerate(axs1.flat):
    store0=[]
    store1=[]
    store2=[]
    store3=[]
    store4=[]
    store5=[]
    store6=[]
    store7=[]
    for p in range(len(taskcolumn)):
         if taskcolumn[p] == 1:
            store1.append(p)
         elif taskcolumn[p] == 2:
            store2.append(p)
         elif taskcolumn[p] == 3:
            store3.append(p)
         elif taskcolumn[p] == 4:
            store4.append(p)
         elif taskcolumn[p] == 5:
            store5.append(p)
         elif taskcolumn[p] == 6:
            store6.append(p)
         elif taskcolumn[p] == 7:
            store7.append(p)
         elif taskcolumn[p] == 0:
            store0.append(p)
            
    ax.plot(time, norm.iloc[:,i],'gray',linewidth=0.5, label = "Idle")      
    ax.plot(time[store1],norm.iloc[store1,i],'r',linewidth=0.5, label = "TF")
    ax.plot(time[store2],norm.iloc[store2,i],'b',linewidth=0.5, label = "IFF" )
    ax.plot(time[store3],norm.iloc[store3,i],'g',linewidth=0.5, label = "MFF")
    ax.plot(time[store4],norm.iloc[store4,i],'m',linewidth=0.5, label = "RFF")
    ax.plot(time[store5],norm.iloc[store5,i],'y',linewidth=0.5, label = "PFF")
    ax.plot(time[store6],norm.iloc[store6,i],'cadetblue',linewidth=0.5, label = "WE")
    ax.plot(time[store7],norm.iloc[store7,i],'darkorange',linewidth=0.5, label = "WF")
    #ax.plot(time,emgval.iloc[:,i])
    ax.set_title(titles[i],fontname="Times New Roman", fontweight="bold",fontsize=9)
    ax.set_xlabel('Time (sec)',fontname="Times New Roman",fontsize=9)
    ax.set_ylabel('(%) ',fontname="Times New Roman",fontsize=9)
    ax.tick_params(axis='both', labelsize=8)
    ax.set_xlim([0, time[end]])
    

plt.tight_layout()

L = ax.legend(loc='center', bbox_to_anchor=(1.2, 4.1),fontsize = 9)
plt.setp(L.texts, family='Times New Roman')
plt.suptitle('NORMALIZED DATA', fontname="Times New Roman", fontweight="bold",fontsize=12)

plt.show()

# %%
#ABSOLUTE MEAN VALUE OF NORMALIZED DATA OF EACH SUBJECT 
#Stored in normalized_data for array and norm as data frame

from statistics import mean
import numpy as np
import pandas as pd
import statistics

#CAMBIAR EL ID DEL SUJETO AQUI PARA GUARDAR INDIVIDUALMENTE EN UN CSV LOS 5 SUJETOS
dataval = dataframes[3]
#use of data normalized
emgval = norm
numemg = [1,2,3,4,5,6,7,8]
tasks = [1,2,3,4,5,6,7]
taskval = dataval.iloc[:,1]
indtask1 = np.zeros((21, 9))
titles = ['Task number','EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']
indtask1 = np.array([tuple(row) for row in indtask1], dtype=[(title, float) for title in titles])

#TASK 1,2,3,4,5,6,7
row = 0
for k, tasknumber in enumerate(tasks):
    start = 0
    for j in range(1,(len(taskval))):
        if taskval[j] == tasknumber and taskval[j-1] == 0:
            start = j
        elif taskval[j] == tasknumber and taskval[j + 1] == 0:
            count = 0
            end = j
            for i in numemg:
                segment = emgval.iloc[(start):(end+1),count]
                indtask1[row][count+1] = statistics.mean(segment)
                count += 1
                
            indtask1[row][0] = tasknumber
            row += 1

#TASK 0 

indtask2 = np.zeros((22, 9))
titles = ['Task number','EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']
indtask2 = np.array([tuple(row) for row in indtask2], dtype=[(title, float) for title in titles])
row = 0
start = 0
for j in range(1,(len(taskval))-1):
    if taskval[j] == 0 and taskval[j-1] in range(1, 8):
        start = j
    elif taskval[j] == 0 and taskval[j+1] in range(1, 8):
        count = 0
        end = j
        for i in numemg:
            segment = emgval.iloc[(start):(end+1),count]
            indtask2[row][count+1] = statistics.mean(segment)
            count += 1
        indtask2[row][0] = 0
        row += 1
#last segment
end = j+1
count = 0
for i in numemg:
    segment = emgval.iloc[(start):(end+1),count]
    indtask2[row][count+1] = statistics.mean(segment)
    count += 1
indtask2[row][0] = 0

indtask = np.append(indtask2, indtask1)
print(indtask)
#CHANGE THE NAME TO SAVE THE CSV FILE ACCORDING TO THE SUBJECT
np.savetxt("ABS3.csv", indtask, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 12
#      10 dataval = dataframes[3]
#      11 #use of data normalized
# ---> 12 emgval = norm
#      13 numemg = [1,2,3,4,5,6,7,8]
#      14 tasks = [1,2,3,4,5,6,7]
#
# NameError: name 'norm' is not defined

# %%
#SIMPLE SQUARE INTEGRAL (SSI) OF NORMALIZED DATA OF SUBJECT 3

#Stored in normalized_data for array and norm as data frame

from statistics import mean
import numpy as np
import pandas as pd
import statistics

#CAMBIAR EL ID DEL SUJETO AQUI PARA GUARDAR INDIVIDUALMENTE EN UN CSV
dataval = dataframes[3]
#use of data normalized
normsquared = np.square(norm) 
emgval = normsquared
numemg = [1,2,3,4,5,6,7,8]
tasks = [1,2,3,4,5,6,7]
taskval = dataval.iloc[:,1]

indtask1 = np.zeros((21, 9))
titles = ['Task number','EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']
indtask1 = np.array([tuple(row) for row in indtask1], dtype=[(title, float) for title in titles])

#TASK 1,2,3,4,5,6,7
row = 0
for k, tasknumber in enumerate(tasks):
    start = 0
    for j in range(1,(len(taskval))):
        if taskval[j] == tasknumber and taskval[j-1] == 0:
            start = j
        elif taskval[j] == tasknumber and taskval[j + 1] == 0:
            count = 0
            end = j
            for i in numemg:
                segment = emgval.iloc[(start):(end+1),count]
                indtask1[row][count+1] = statistics.mean(segment)
                count += 1
                
            indtask1[row][0] = tasknumber
            row += 1

#TASK 0 
indtask2 = np.zeros((22, 9))
titles = ['Task number','EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']
indtask2 = np.array([tuple(row) for row in indtask2], dtype=[(title, float) for title in titles])
row = 0
start = 0
for j in range(1,(len(taskval))-1):
    if taskval[j] == 0 and taskval[j-1] in range(1, 8):
        start = j
    elif taskval[j] == 0 and taskval[j+1] in range(1, 8):
        count = 0
        end = j
        for i in numemg:
            segment = emgval.iloc[(start):(end+1),count]
            indtask2[row][count+1] = statistics.mean(segment)
            count += 1
        indtask2[row][0] = 0
        row += 1
#last segment
end = j+1
count = 0
for i in numemg:
    segment = emgval.iloc[(start):(end+1),count]
    indtask2[row][count+1] = statistics.mean(segment)
    count += 1
indtask2[row][0] = 0
indtask = np.append(indtask2, indtask1)
#CHANGE THE NAME TO SAVE THE CSV FILE ACCORDING TO THE SUBJECT
np.savetxt("SSI3.csv", indtask, delimiter=",")

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
#https://www.baeldung.com/cs/svm-multiclass-classification

#EJEMPLO

from sklearn import svm, datasets
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
iris = datasets.load_iris()
X = iris.data[:, :2] #FEATURES
y = iris.target #LABELS
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, train_size=0.80, test_size=0.20, random_state=101)
rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, y_train)
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
# Out:
# Accuracy (Polynomial Kernel):  70.00
# F1 (Polynomial Kernel):  69.67
# Accuracy (RBF Kernel):  76.67
# F1 (RBF Kernel):  76.36

# %%
#discarded
#SVM CON MEAN ABS VALUE
import pandas as pd
datasvm = pd.read_csv("data/EMG/ALLABS12345.csv")
from sklearn import svm, datasets
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
#from sklearn.metrics import precision_score
X = datasvm.iloc[:,1:].values #features
y = datasvm.iloc[:,0].values #labels
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, train_size=0.80, test_size=0.20, random_state=47)
rbf = svm.SVC(kernel='rbf', gamma=0.85, C=4).fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=4).fit(X_train, y_train)
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
# Out:
# Accuracy (Polynomial Kernel):  90.48
# F1 (Polynomial Kernel):  90.69
# Accuracy (RBF Kernel):  85.71
# F1 (RBF Kernel):  85.93

# %%
#CONFUSION MATRIX ABS
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Generate the confusion matrix poly
cmpoly= confusion_matrix(y_test, poly_pred)
# Plot the confusion matrix as a heatmap
ax = sns.heatmap(cmpoly, annot=True, cmap="Blues",fmt='g')
ax.set_title('Confusion Matrix SVM')
ax.set_xlabel('Gesture Predicted');ax.set_ylabel('Actual Gesture'); 
ax.xaxis.set_label_position('top') 
ax.xaxis.set_ticklabels(['TF', 'IFF', 'MFF', 'RFF', 'PFF', 'WE', 'WF'])
ax.xaxis.tick_top()
ax.yaxis.set_ticklabels(['TF', 'IFF', 'MFF', 'RFF', 'PFF', 'WE', 'WF'])


# Generate the confusion matrix rbf
#cmrbf= confusion_matrix(y_test, rbf_pred)
# Plot the confusion matrix as a heatmap
#sns.heatmap(cmrbf, annot=True, cmap="Blues")
# Out:
# [Text(0, 0.5, 'TF'),
#  Text(0, 1.5, 'IFF'),
#  Text(0, 2.5, 'MFF'),
#  Text(0, 3.5, 'RFF'),
#  Text(0, 4.5, 'PFF'),
#  Text(0, 5.5, 'WE'),
#  Text(0, 6.5, 'WF')]

# %%
#discarded
#SVM SSI

import pandas as pd
datasvm = pd.read_csv("data/EMG/ALLSSI12345.csv")
from sklearn import svm, datasets
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
X = datasvm.iloc[:,1:].values #features
y = datasvm.iloc[:,0].values #labels
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, train_size=0.80, test_size=0.20, random_state = 47)
rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, y_train)
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
# Out:
# Accuracy (Polynomial Kernel):  52.38
# F1 (Polynomial Kernel):  52.49
# Accuracy (RBF Kernel):  19.05
# F1 (RBF Kernel):  8.44

# %%
#discarded
#SVM ABS AND SSI
#tasks 1-7
import pandas as pd
#join abs and ssi from excel and input here
datasvm = pd.read_csv("data/EMG/ALLABSSSI.csv")
from sklearn import svm, datasets
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
X = datasvm.iloc[:,1:].values #features
y = datasvm.iloc[:,0].values #labels
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, train_size=0.80, test_size=0.20, random_state=47)
rbf = svm.SVC(kernel='rbf', gamma=0.95, C=3).fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=3).fit(X_train, y_train)
linear = svm.SVC(kernel = 'linear').fit(X_train, y_train)
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)
lin_pred = linear.predict(X_test)

linear_accuracy = accuracy_score(y_test, lin_pred)
linear_f1 = f1_score(y_test, lin_pred, average='weighted')
linear_precision = precision_score(y_test, lin_pred, average =  'weighted')
linear_recall = recall_score(y_test, lin_pred, average ='weighted')
print('Accuracy (Linear Kernel): ', "%.2f" % (linear_accuracy*100))
print('F1 (Linear Kernel): ', "%.2f" % (linear_f1*100))
print("Precision (Linear Kernel):", "%.2f" % (linear_precision*100))
print("Recall (Linear Kernel):", "%.2f" % (linear_recall*100))

poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
poly_precision = precision_score(y_test, poly_pred, average =  'weighted')
poly_recall = recall_score(y_test, poly_pred, average ='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
print("Precision (Polynomial Kernel):", "%.2f" % (poly_precision*100))
print("Recall (Polynomial Kernel):", "%.2f" % (poly_recall*100))

rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
rbf_precision = precision_score(y_test, rbf_pred, average =  'weighted')
rbf_recall = recall_score(y_test, rbf_pred, average ='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
print("Precision (RBF Kernel):", "%.2f" % (rbf_precision*100))
print("Recall (RBF Kernel):", "%.2f" % (rbf_recall*100))
# Out:
# Accuracy (Linear Kernel):  47.62
# F1 (Linear Kernel):  48.57
# Precision (Linear Kernel): 58.25
# Recall (Linear Kernel): 47.62
# Accuracy (Polynomial Kernel):  90.48
# F1 (Polynomial Kernel):  90.69
# Precision (Polynomial Kernel): 93.65
# Recall (Polynomial Kernel): 90.48
# Accuracy (RBF Kernel):  95.24
# F1 (RBF Kernel):  95.45
# Precision (RBF Kernel): 96.83
# Recall (RBF Kernel): 95.24

# %%
#CM WITH ALL ABS AND SSI
#CONFUSION MATRIX
print(y_test)
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Generate the confusion matrix poly
cmpoly= confusion_matrix(y_test, lin_pred)
# Plot the confusion matrix as a heatmap
ax = sns.heatmap(cmpoly, annot=True, cmap="Blues",fmt='g')
ax.set_title('Confusion Matrix SVM (Linear)')
ax.set_xlabel('Gesture Predicted');ax.set_ylabel('Actual Gesture'); 
ax.xaxis.set_label_position('top') 
ax.xaxis.set_ticklabels(['TF', 'IFF', 'MFF', 'RFF', 'PFF', 'WE', 'WF'])
ax.xaxis.tick_top()
ax.yaxis.set_ticklabels(['TF', 'IFF', 'MFF', 'RFF', 'PFF', 'WE', 'WF'])
# Out:
# [4. 1. 5. 7. 2. 7. 1. 3. 2. 6. 5. 5. 6. 2. 7. 1. 4. 3. 5. 5. 1.]
# [Text(0, 0.5, 'TF'),
#  Text(0, 1.5, 'IFF'),
#  Text(0, 2.5, 'MFF'),
#  Text(0, 3.5, 'RFF'),
#  Text(0, 4.5, 'PFF'),
#  Text(0, 5.5, 'WE'),
#  Text(0, 6.5, 'WF')]

# %%
#discarded
#SVM ABS AND SSI
#tasks 0-7
import pandas as pd
datasvm = pd.read_csv("data/EMG/TODO.csv")
from sklearn import svm, datasets
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
X = datasvm.iloc[:,1:].values #features
y = datasvm.iloc[:,0].values #labels
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, train_size=0.80, test_size=0.20, random_state=44)
rbf = svm.SVC(kernel='rbf', gamma=0.6, C=3.3).fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=5, C=1).fit(X_train, y_train)
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
poly_precision = precision_score(y_test, poly_pred, average =  'weighted')
poly_recall = recall_score(y_test, poly_pred, average ='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
print("Precision (Polynomial Kernel):", "%.2f" % (poly_precision*100))
print("Recall (Polynomial Kernel):", "%.2f" % (poly_recall*100))
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
rbf_precision = precision_score(y_test, rbf_pred, average =  'weighted')
rbf_recall = recall_score(y_test, rbf_pred, average ='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
print("Precision (RBF Kernel):", "%.2f" % (rbf_precision*100))
print("Recall (RBF Kernel):", "%.2f" % (rbf_recall*100))
# Out:
# Accuracy (Polynomial Kernel):  51.16
# F1 (Polynomial Kernel):  42.25
# Precision (Polynomial Kernel): 39.11
# Recall (Polynomial Kernel): 51.16
# Accuracy (RBF Kernel):  60.47
# F1 (RBF Kernel):  46.88
# Precision (RBF Kernel): 41.58
# Recall (RBF Kernel): 60.47
# c:\Users\sofia\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\sofia\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#CM WITH ALL ABS AND SSI
#CONFUSION MATRIX
print(y_test)
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Generate the confusion matrix poly
cmpoly= confusion_matrix(y_test, rbf_pred)
# Plot the confusion matrix as a heatmap
ax = sns.heatmap(cmpoly, annot=True, cmap="Blues",fmt='g')
ax.set_title('Confusion Matrix SVM (RBF)')
ax.set_xlabel('Gesture Predicted');ax.set_ylabel('Actual Gesture'); 
ax.xaxis.set_label_position('top') 
ax.xaxis.set_ticklabels(['IDLE', 'TF', 'IFF', 'MFF', 'RFF', 'PFF', 'WE', 'WF'])
ax.xaxis.tick_top()
ax.yaxis.set_ticklabels(['IDLE', 'TF', 'IFF', 'MFF', 'RFF', 'PFF', 'WE', 'WF'])


# Generate the confusion matrix rbf
#cmrbf= confusion_matrix(y_test, rbf_pred)
# Plot the confusion matrix as a heatmap
#sns.heatmap(cmrbf, annot=True, cmap="Blues")
# Out:
# [2. 3. 5. 6. 0. 0. 7. 4. 0. 0. 0. 0. 0. 0. 0. 6. 0. 7. 0. 7. 4. 0. 2. 5.
#  0. 0. 0. 0. 3. 0. 0. 2. 1. 7. 0. 0. 0. 0. 1. 6. 0. 0. 0.]
# [Text(0, 0.5, 'IDLE'),
#  Text(0, 1.5, 'TF'),
#  Text(0, 2.5, 'IFF'),
#  Text(0, 3.5, 'MFF'),
#  Text(0, 4.5, 'RFF'),
#  Text(0, 5.5, 'PFF'),
#  Text(0, 6.5, 'WE'),
#  Text(0, 7.5, 'WF')]

# %% [markdown]
# #NEW APPROACH: ROLLING

# %%
#ROLLING (absolute) MEAN OF NORMALIZED DATA

#FIRST: NORMALIZE
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
import numpy as np
#repeat for each subject changing id number
id = 3
dataval= dataframes[id]
emgval = np.abs(dataval.iloc[:,2:10] * 0.045)
data = np.array(emgval)
normalized_data = np.empty_like(data)
scalers = []
for i in range(data.shape[1]):
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data[:, i].reshape(-1, 1))
    scalers.append(scaler)
for i, scaler in enumerate(scalers):
    normalized_data[:, i] = scaler.transform(data[:, i].reshape(-1, 1)).flatten()
  
taskval = dataval.iloc[:,1]
newdata = np.zeros(((data.shape[0]),9))
newdata[:, 0] = taskval
newdata[:, 1:] = normalized_data

#SECOND: ROLLING MEAN FOR EACH COLUMN
import pandas as pd
newdata = pd.DataFrame(newdata) #convert to dataframe
roll = newdata.rolling(window=10, step=1).mean()
#np.savetxt("rm.csv", roll, delimiter=",")
roll2 = np.zeros(roll.shape)
#For subject #4 eliminate one repetition of task 1 (it has been found that there are 2 repetitions instead of 3 for task 1 in subject 4)
repetitions = [1,1,1,2,2,2,3,3,3,4,4,4,5,5,5,6,6,6,7,7,7]
count=-1
#he establecido un treshold para que asigne un task u otro y no haya decimales y
#que en total solo sean 7 tasks

for i in range(1,(len(roll))):
        if not roll.iloc[i,0] == 0 and roll.iloc[i-1,0] == 0:
            count += 1
        if not roll.iloc[i,0] == 0 and roll.iloc[i,0] < (repetitions[count]/2):
            roll2[i,0] = 0
        elif not roll.iloc[i,0] == 0 and roll.iloc[i,0] >= (repetitions[count]/2):
            roll2[i,0] = repetitions[count]
#eliminate first 2 values NaN           
roll2[9:,1:]= roll.iloc[9:,1:]
roll3 = roll2[9:,:]
#change the csv name according to the subject
np.savetxt("data/EMG/rm1.csv", roll3, delimiter=",")

# %%
#Join 5 subjects
rm1 = pd.read_csv("data/EMG/rm1.csv", header = None)
rm2 = pd.read_csv("data/EMG/rm2.csv", header = None)
rm3 = pd.read_csv("data/EMG/rm3.csv", header = None)
rm4 = pd.read_csv("data/EMG/rm4.csv", header = None)
rm5 = pd.read_csv("data/EMG/rm5.csv", header = None)

all = [rm1, rm2, rm3,rm4, rm5]
rmw10s8 = pd.DataFrame()
for file in all:
    rmw10s8 = rmw10s8.append(file, ignore_index=True)
#np.savetxt("data/EMG/rmw10s8.csv", rmw10s8, delimiter=",")
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_16880\2380317583.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   rmw10s8 = rmw10s8.append(file, ignore_index=True)

# %%
#ROLLING SSI OF NORMALIZED DATA

#FIRST: NORMALIZE AND SQUARED
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
import numpy as np
#repeat for each subject changing id number
id = 3
dataval= dataframes[id]
emgval = np.abs(dataval.iloc[:,2:10] * 0.045)
data = np.array(emgval)
normalized_data = np.empty_like(data)
scalers = []
for i in range(data.shape[1]):
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data[:, i].reshape(-1, 1))
    scalers.append(scaler)
for i, scaler in enumerate(scalers):
    normalized_data[:, i] = scaler.transform(data[:, i].reshape(-1, 1)).flatten()

normsquared = np.square(normalized_data)   
taskval = dataval.iloc[:,1]
newdata = np.zeros(((data.shape[0]),9))
newdata[:, 0] = taskval
newdata[:, 1:] = normsquared

#SECOND: ROLLING SSI FOR EACH COLUMN
import pandas as pd
newdata = pd.DataFrame(newdata) #convert to dataframe
roll = newdata.rolling(window=10, step=1).mean()
#np.savetxt("rm.csv", roll, delimiter=",")
roll2 = np.zeros(roll.shape)
#For subject #4 eliminate one repetition of task 1 (it has been found that there are 2 repetitions instead of 3 for task 1 in subject 4)
repetitions = [1,1,1,2,2,2,3,3,3,4,4,4,5,5,5,6,6,6,7,7,7]
count=-1
#he establecido un treshold para que asigne un task u otro y no haya decimales y
#que en total solo sean 7 tasks

for i in range(1,(len(roll))):
        if not roll.iloc[i,0] == 0 and roll.iloc[i-1,0] == 0:
            count += 1
        if not roll.iloc[i,0] == 0 and roll.iloc[i,0] < (repetitions[count]/2):
            roll2[i,0] = 0
        elif not roll.iloc[i,0] == 0 and roll.iloc[i,0] >= (repetitions[count]/2):
            roll2[i,0] = repetitions[count]
#eliminate first 2 values NaN           
roll2[9:,1:]= roll.iloc[9:,1:]
roll3 = roll2[9:,:]
#change the csv name according to the subject
np.savetxt("data/EMG/rs3.csv", roll3, delimiter=",")

# %%
#Join 5 subjects
rs1 = pd.read_csv("data/EMG/rs1.csv", header = None)
rs2 = pd.read_csv("data/EMG/rs2.csv", header = None)
rs3 = pd.read_csv("data/EMG/rs3.csv", header = None)
rs4 = pd.read_csv("data/EMG/rs4.csv", header = None)
rs5 = pd.read_csv("data/EMG/rs5.csv", header = None)

all = [rs1, rs2, rs3,rs4, rs5]
rsw10s8 = pd.DataFrame()
for file in all:
    rsw10s8 = rsw10s8.append(file, ignore_index=True)
#np.savetxt("data/EMG/rmw10s8.csv", rmw10s8, delimiter=",")
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_16880\3739140736.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   rsw10s8 = rsw10s8.append(file, ignore_index=True)

# %%
#JOIN RM AND RS

datasvm = pd.concat([rmw10s8, rmw10s8.iloc[:,1:]], axis=1)

# %%
#SVM
import pandas as pd
from sklearn import svm, datasets
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score, recall_score
X = datasvm.iloc[:,1:].values #features
y = datasvm.iloc[:,0].values #labels
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, train_size=0.80, test_size=0.20, random_state=44)
rbf = svm.SVC(kernel='rbf', gamma=4, C=5).fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=5, C=7).fit(X_train, y_train)
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)

#print accuracy etc
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))

rbf_precision = precision_score(y_test, rbf_pred, average =  'weighted')
rbf_recall = recall_score(y_test, rbf_pred, average ='weighted')
print('Precision (RBF Kernel): ', "%.2f" % (rbf_precision*100))
print('Recall (RBF Kernel): ', "%.2f" % (rbf_recall*100))
poly_precision = precision_score(y_test, poly_pred, average =  'weighted')
poly_recall = recall_score(y_test, poly_pred, average ='weighted')
print('Precision (poly Kernel): ', "%.2f" % (poly_precision*100))
print('Recall (poly Kernel): ', "%.2f" % (poly_recall*100))

#BETTER RBF, WE WILL USE THIS ONE
# Out:
# Accuracy (Polynomial Kernel):  85.88
# F1 (Polynomial Kernel):  82.90
# Accuracy (RBF Kernel):  95.34
# F1 (RBF Kernel):  95.26
# Precision (RBF Kernel):  95.29
# Recall (RBF Kernel):  95.34
# Precision (poly Kernel):  86.60
# Recall (poly Kernel):  85.88

# %%
#SAVE MODEL with joblib
#hay pickle, joblib, json, 
import joblib

# save the model to disk
filename = 'svm2_model.sav'
joblib.dump(rbf, filename)
 
# load the model from disk
loaded_rbf = joblib.load(filename)

# %%
#confusion matrix
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"

from sklearn.metrics import confusion_matrix
import seaborn as sns
# Generate the confusion matrix poly
cmpoly= confusion_matrix(y_test, poly_pred)
# Plot the confusion matrix as a heatmap

ax = sns.heatmap(cmpoly, annot=True, cmap="Blues",fmt='g')
ax.set_title('Confusion Matrix SVM (Polynomial)')
ax.set_xlabel('Gesture Predicted');ax.set_ylabel('Actual Gesture'); 
ax.xaxis.set_label_position('top') 
ax.xaxis.set_ticklabels(['IDLE', 'TF', 'IFF', 'MFF', 'RFF', 'PFF', 'WE', 'WF'])
ax.xaxis.tick_top()
ax.yaxis.set_ticklabels(['IDLE', 'TF', 'IFF', 'MFF', 'RFF', 'PFF', 'WE', 'WF'])
# Out:
# [Text(0, 0.5, 'IDLE'),
#  Text(0, 1.5, 'TF'),
#  Text(0, 2.5, 'IFF'),
#  Text(0, 3.5, 'MFF'),
#  Text(0, 4.5, 'RFF'),
#  Text(0, 5.5, 'PFF'),
#  Text(0, 6.5, 'WE'),
#  Text(0, 7.5, 'WF')]

# %%
#DIBUJO RAW Y ROLLING
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
import pandas as pd



emgval = roll3[:,1]
samples = list(range(0,len(emgval)))

time = samples
taskcolumn = roll3[:,0]
store0=[]
store1=[]
store2=[]
store3=[]
store4=[]
store5=[]
store6=[]
store7=[]

for p in range(len(taskcolumn)):
    if taskcolumn[p] == 1:
       store1.append(p)
    elif taskcolumn[p] == 2:
       store2.append(p)
    elif taskcolumn[p] == 3:
       store3.append(p)
    elif taskcolumn[p] == 4:
       store4.append(p)
    elif taskcolumn[p] == 5:
       store5.append(p)
    elif taskcolumn[p] == 6:
       store6.append(p)
    elif taskcolumn[p] == 7:
       store7.append(p)
    elif taskcolumn[p] == 0:
       store0.append(p)

#plt.plot(time[store0],emgval[store0],'gray')  
plt.plot(time, emgval,'gray',linewidth=0.5)      
plt.plot(store1,emgval[store1],'r',linewidth=0.5)
plt.plot(store2,emgval[store2],'b',linewidth=0.5)
plt.plot(store3,emgval[store3],'g',linewidth=0.5)
plt.plot(store4,emgval[store4],'m',linewidth=0.5)
plt.plot(store5,emgval[store5],'y',linewidth=0.5)
plt.plot(store6,emgval[store6],'cadetblue',linewidth=0.5)
plt.plot(store7,emgval[store7],'darkorange',linewidth=0.5)

plt.xlabel('Segments',fontname="Times New Roman",fontweight=15)
plt.ylabel( '(%)',fontname="Times New Roman")
plt.title('Rolling SSI',fontname="Times New Roman", fontweight="bold")
plt.xlim(0,37393)
plt.ylim(-0.4,1)

L = plt.legend(["Idle","TF","IFF","MFF","RFF","PFF","WE","WF"],loc ='lower right',prop={'size':7}, ncol = 2)      
plt.setp(L.texts, family='Times New Roman',fontsize = 10)
plt.show()

# %%
# PRUEBA
# NORMALIZATION A MANO
#maxval = [384697, 359768, 493441, 271792, 297868, 359203, 68659, 451527] *0.045
#minval = [311479, 286027, 418289, 172654, 219494, 293226, 13830, 383736] * 0.045
maxval = [17311.365, 16189.56, 22204.845, 12230.64, 13404.06, 16164.135, 3089.655, 20318.715]
minval = [14016.555, 12871.215, 18823.005, 7769.43, 9877.23, 13195.17, 622.35, 17268.12]
emgval = np.abs(dataval.iloc[0,2:10] * 0.045)
data = np.array(emgval)
normalized_data = np.empty_like(data)

for i in range(data.shape[0]):
    normalized_data[i] = ((2 * (data[i] - minval[i]) / (maxval[i] - minval[i])) - 1)
    
print(normalized_data)
# Out:
# [-0.71900352 -0.51983293 -0.50045242 -0.53174363 -0.37282772 -0.09307789
#   0.69851721 -0.18363795]

# %%
#my own data set
#PRUEBAS 
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
import joblib

#RECORD CSV FROM SDK MINDROVE
dataval = pd.read_csv("data/EMG/try.csv", delimiter=";")



#ROLLING (absolute) MEAN OF NORMALIZED DATA
#FIRST: NORMALIZE
emgval = np.abs(dataval.iloc[:,2:10].values * 0.045)
data = np.array(emgval)
normalized_data = np.empty_like(data)
scalers = []
for i in range(data.shape[1]):
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data[:, i].reshape(-1, 1))
    scalers.append(scaler)
for i, scaler in enumerate(scalers):
    normalized_data[:, i] = scaler.transform(data[:, i].reshape(-1, 1)).flatten()

#SECOND: ROLLING MEAN FOR EACH COLUMN
newdata = pd.DataFrame(normalized_data) #convert to dataframe
roll = newdata.rolling(window=10, step=1).mean()
rm1805 =  roll.iloc[9:,:]


#ROLLING SSI OF NORMALIZED DATA

#FIRST: SQUARED

normsquared = np.square(normalized_data)   

#SECOND: ROLLING SSI FOR EACH COLUMN
import pandas as pd
newdata = pd.DataFrame(normsquared) #convert to dataframe
roll = newdata.rolling(window=10, step=1).mean()
rs1805 = roll.iloc[9:,:]

#JOIN RM AND RS

datasvm = pd.concat([rm1805, rs1805], axis=1)

#APPLY MODEL
model = joblib.load("svm2_model.sav")

predict = model.predict(datasvm)
np.savetxt("data/EMG/result3.csv", predict, delimiter=",")

# %%
#RECORD CSV FROM SDK MINDROVE
dataval = pd.read_csv("data/EMG/try.csv")

emgval = dataval.iloc[:,2:10] * 0.045
time = dataval.iloc[:,10] - dataval.iloc[0,10]
data = np.array(emgval)
normalized_data = np.empty_like(data)
scalers = []
for i in range(data.shape[1]):
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data[:, i].reshape(-1, 1))
    scalers.append(scaler)
for i, scaler in enumerate(scalers):
    normalized_data[:, i] = scaler.transform(data[:, i].reshape(-1, 1)).flatten()

#PLOT
fig1, axs1 = plt.subplots(4, 2)
titles = ['EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']
for i, ax in enumerate(axs1.flat):
    ax.plot(time,normalized_data[:,i],linewidth=0.5)
    ax.set_title(titles[i],fontname="Times New Roman", fontweight="bold",fontsize=10)
    ax.set_xlabel('Time (secs)',fontname="Times New Roman",fontsize=10)
    ax.set_ylabel('EMG (microVolts)',fontname="Times New Roman",fontsize=7)
    ax.tick_params(axis='both', labelsize=8)
    ax.set_xlim([0, len(time)])
    
#plt.tight_layout()
#plt.show()

# %%
import matplotlib.pyplot as plt
fig1, axs1 = plt.subplots(4, 2)

dataval= pd.read_csv("data/EMG/try.csv", delimiter = ";")

emgval = np.abs(dataval.iloc[0:28000,0:8] * 0.045)
time = list(range(0, 28000))
data = np.array(emgval)
normalized_data = np.empty_like(data)
scalers = []
for i in range(data.shape[1]):
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data[:, i].reshape(-1, 1))
    scalers.append(scaler)
for i, scaler in enumerate(scalers):
    normalized_data[:, i] = scaler.transform(data[:, i].reshape(-1, 1)).flatten()

titles = ['EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']
for i, ax in enumerate(axs1.flat):
    ax.plot(time,normalized_data[:,i],linewidth=0.5)
    ax.set_title(titles[i],fontname="Times New Roman", fontweight="bold",fontsize=10)
    ax.set_xlabel('Samples',fontname="Times New Roman",fontsize=10)
    ax.set_ylabel('EMG (microVolts)',fontname="Times New Roman",fontsize=7)

plt.tight_layout()
plt.show()

end = len(time)

# %%
#plot new recording
#todos los channels de un id por colores
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
from scipy import signal 
# Create/view notch filter
dataval= pd.read_csv("data/EMG/record1.csv", delimiter = ",")
samp_freq = 500  # Sample frequency (Hz)
notch_freq = 50.0  # Frequency to be removed from signal (Hz)
quality_factor = 20.0  # Quality factor
# Design a notch filter using signal.iirnotch
b, a = signal.iirnotch(notch_freq, quality_factor, samp_freq)
# Compute magnitude response of the designed filter
freq, h = signal.freqz(b, a, fs=2*np.pi)
emgval = np.zeros_like(dataval.iloc[:, 2:10])  # Create an empty array for filtered data
for i in range(8):
    emgval[:, i] = signal.filtfilt(b, a, dataval.iloc[:, i+2])
emgval = np.abs(emgval) * 0.045
#normalization
data = np.array(emgval)
normalized_data = np.empty_like(data)
scalers = []
for i in range(data.shape[1]):
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data[:, i].reshape(-1, 1))
    scalers.append(scaler)
# Normalize each channel separately
for i, scaler in enumerate(scalers):
    normalized_data[:, i] = scaler.transform(data[:, i].reshape(-1, 1)).flatten()
    
emgval = normalized_data
emg_id = 1
columnemg = emg_id + 1
#emgval = dataval.iloc[:,columnemg] * 0.045
time = dataval.iloc[:,10] - dataval.iloc[0,10]
end = len(time)-1
taskcolumn = dataval.iloc[:,1]
fig1, axs1 = plt.subplots(4, 2)


#emgval = dataval.iloc[:,2:10] * 0.045
titles = ['EMG channel #1','EMG channel #2','EMG channel #3','EMG channel #4','EMG channel #5','EMG channel #6','EMG channel #7','EMG channel #8']

for i, ax in enumerate(axs1.flat):
    store0=[]
    store1=[]
    store2=[]
    store3=[]
    store4=[]
    store5=[]
    store6=[]
    store7=[]
    for p in range(len(taskcolumn)):
         if taskcolumn[p] == 1:
            store1.append(p)
         elif taskcolumn[p] == 2:
            store2.append(p)
         elif taskcolumn[p] == 3:
            store3.append(p)
         elif taskcolumn[p] == 4:
            store4.append(p)
         elif taskcolumn[p] == 5:
            store5.append(p)
         elif taskcolumn[p] == 6:
            store6.append(p)
         elif taskcolumn[p] == 7:
            store7.append(p)
         elif taskcolumn[p] == 0:
            store0.append(p)
            
    ax.plot(time, emgval[:,i],'gray',linewidth=0.5, label = "Idle")      
    ax.plot(time[store1],emgval[store1,i],'r',linewidth=0.5, label = "TF")
    ax.plot(time[store2],emgval[store2,i],'b',linewidth=0.5, label = "IFF" )
    ax.plot(time[store3],emgval[store3,i],'g',linewidth=0.5, label = "MFF")
    ax.plot(time[store4],emgval[store4,i],'m',linewidth=0.5, label = "RFF")
    ax.plot(time[store5],emgval[store5,i],'y',linewidth=0.5, label = "PFF")
    ax.plot(time[store6],emgval[store6,i],'cadetblue',linewidth=0.5, label = "WE")
    ax.plot(time[store7],emgval[store7,i],'darkorange',linewidth=0.5, label = "WF")
    #ax.plot(time,emgval.iloc[:,i])
    ax.set_title(titles[i],fontname="Times New Roman", fontweight="bold",fontsize=9)
    ax.set_xlabel('Time (sec)',fontname="Times New Roman",fontsize=9)
    ax.set_ylabel('(%)',fontname="Times New Roman",fontsize=7)
    ax.tick_params(axis='both', labelsize=8)
    ax.set_xlim([0, time[end]])
    

plt.tight_layout()
L = ax.legend(loc='center', bbox_to_anchor=(1.2, 4.1),fontsize = 9)
plt.setp(L.texts, family='Times New Roman')
plt.suptitle('NORMALIZED DATA', fontname="Times New Roman", fontweight="bold",fontsize=12)
plt.show()
plt.show()
